# %%
# Importing the Libraries -
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15,8]
import scipy.stats as stats
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Changing the Default Display Parameters -
pd.set_option('max_columns',90)
pd.set_option('max_rows',300)

# %% [markdown]
# # Data Description :

# %% [markdown]
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density
#
# LotFrontage: Linear feet of street connected to property
#
# LotArea: Lot size in square feet
#
# Street: Type of road access to property
#
#        Grvl	Gravel
#        Pave	Paved
#
# Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access
#
# LotShape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
#
# LandContour: Flatness of the property
#
#        Lvl	Near Flat/Level
#        Bnk	Banked - Quick and significant rise from street grade to building
#        HLS	Hillside - Significant slope from side to side
#        Low	Depression
#
# Utilities: Type of utilities available
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only
#
# LotConfig: Lot configuration
#
#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property
#
# LandSlope: Slope of property
#
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
#
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# Condition1: Proximity to various conditions
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# Condition2: Proximity to various conditions (if more than one is present)
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# BldgType: Type of dwelling
#
#        1Fam	Single-family Detached
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit
#
# HouseStyle: Style of dwelling
#
#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level
#
# OverallQual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# OverallCond: Rates the overall condition of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# YearBuilt: Original construction date
#
# YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#
# RoofStyle: Type of roof
#
#        Flat	Flat
#        Gable	Gable
#        Gambrel	Gabrel (Barn)
#        Hip	Hip
#        Mansard	Mansard
#        Shed	Shed
#
# RoofMatl: Roof material
#
#        ClyTile	Clay or Tile
#        CompShg	Standard (Composite) Shingle
#        Membran	Membrane
#        Metal	Metal
#        Roll	Roll
#        Tar&Grv	Gravel & Tar
#        WdShake	Wood Shakes
#        WdShngl	Wood Shingles
#
# Exterior1st: Exterior covering on house
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# MasVnrType: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone
#
# MasVnrArea: Masonry veneer area in square feet
#
# ExterQual: Evaluates the quality of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# ExterCond: Evaluates the present condition of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# Foundation: Type of foundation
#
#        BrkTil	Brick & Tile
#        CBlock	Cinder Block
#        PConc	Poured Contrete
#        Slab	Slab
#        Stone	Stone
#        Wood	Wood
#
# BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square feet of basement area
#
# Heating: Type of heating
#
#        Floor	Floor Furnace
#        GasA	Gas forced warm air furnace
#        GasW	Gas hot water or steam heat
#        Grav	Gravity furnace
#        OthW	Hot water or steam heat other than gas
#        Wall	Wall furnace
#
# HeatingQC: Heating quality and condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# CentralAir: Central air conditioning
#
#        N	No
#        Y	Yes
#
# Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed
#
# 1stFlrSF: First Floor square feet
#
# 2ndFlrSF: Second floor square feet
#
# LowQualFinSF: Low quality finished square feet (all floors)
#
# GrLivArea: Above grade (ground) living area square feet
#
# BsmtFullBath: Basement full bathrooms
#
# BsmtHalfBath: Basement half bathrooms
#
# FullBath: Full bathrooms above grade
#
# HalfBath: Half baths above grade
#
# Bedroom: Bedrooms above grade (does NOT include basement bedrooms)
#
# Kitchen: Kitchens above grade
#
# KitchenQual: Kitchen quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
# GarageType: Garage location
#
#        2Types	More than one type of garage
#        Attchd	Attached to home
#        Basment	Basement Garage
#        BuiltIn	Built-In (Garage part of house - typically has room above garage)
#        CarPort	Car Port
#        Detchd	Detached from home
#        NA	No Garage
#
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
# GarageCars: Size of garage in car capacity
#
# GarageArea: Size of garage in square feet
#
# GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# PavedDrive: Paved driveway
#
#        Y	Paved
#        P	Partial Pavement
#        N	Dirt/Gravel
#
# WoodDeckSF: Wood deck area in square feet
#
# OpenPorchSF: Open porch area in square feet
#
# EnclosedPorch: Enclosed porch area in square feet
#
# 3SsnPorch: Three season porch area in square feet
#
# ScreenPorch: Screen porch area in square feet
#
# PoolArea: Pool area in square feet
#
# PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool
#
# Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence
#
# MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None
#
# MiscVal: $Value of miscellaneous feature
#
# MoSold: Month Sold (MM)
#
# YrSold: Year Sold (YYYY)
#
# SaleType: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other
#
# SaleCondition: Condition of sale
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)

# %%
# Reading the Data -
house_df = pd.read_csv('HousePrices.csv')
house_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# We can drop the ID column as it has no importance for analysis.
house_df = house_df.drop("Id",axis=1)

# %%
# Understanding the variables in the Data -
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
# There are some variable which have been miscategorised as Integer, when they should be categorical.
# For eg. - MSSubClass, OverallQual, OverallCond
# MoSold Can be cast as object with the name of the months.
# We can create a new variable to describe if a house was remodelled or not.
# We can also create a variable to calculate the age of the building.

# %%
house_df['MSSubClass'] = house_df['MSSubClass'].astype('object')

# %%
house_df['MoSold'].value_counts()
# Out:
# 6     253
# 7     234
# 5     204
# 4     141
# 8     122
# 3     106
# 10     89
# 11     79
# 9      63
# 12     59
# 1      58
# 2      52
# Name: MoSold, dtype: int64

# %%
house_df['MonthSold'] = house_df['MoSold'].map({1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',
                                               7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'})

# %%
house_df[['YearBuilt','YrSold']]
# Out:
#       YearBuilt  YrSold
# 0          2003    2008
# 1          1976    2007
# 2          2001    2008
# 3          1915    2006
# 4          2000    2008
# ...         ...     ...
# 1455       1999    2007
# 1456       1978    2010
# 1457       1941    2010
# 1458       1950    2010
# 1459       1965    2008
#
# [1460 rows x 2 columns]

# %%
house_df['Age_At_Sale'] = house_df['YrSold'] - house_df['YearBuilt']

# %%
house_df[house_df['YearBuilt']>house_df['YrSold']]
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, MonthSold, Age_At_Sale]
# Index: []

# %%
house_df["Age"] = 2021 - house_df['YearBuilt']

# %%
house_df[house_df['GarageYrBlt']<house_df['YearBuilt']][['GarageYrBlt','YearBuilt','YrSold']]
# Out:
#       GarageYrBlt  YearBuilt  YrSold
# 29         1920.0       1927    2008
# 93         1900.0       1910    2007
# 324        1961.0       1967    2010
# 600        2003.0       2005    2006
# 736        1949.0       1950    2006
# 1103       1954.0       1959    2006
# 1376       1925.0       1930    2008
# 1414       1922.0       1923    2008
# 1418       1962.0       1963    2008

# %%
house_df.head()
# Out:
#   MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour  \
# 0         60       RL         65.0     8450   Pave   NaN      Reg         Lvl
# 1         20       RL         80.0     9600   Pave   NaN      Reg         Lvl
# 2         60       RL         68.0    11250   Pave   NaN      IR1         Lvl
# 3         70       RL         60.0     9550   Pave   NaN      IR1         Lvl
# 4         60       RL         84.0    14260   Pave   NaN      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
# Checking for Null / Missing Values -
house_df.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# GarageCond         81
# GarageYrBlt        81
# GarageType         81
# GarageFinish       81
# GarageQual         81
# BsmtExposure       38
# BsmtFinType2       38
# BsmtQual           37
# BsmtCond           37
# BsmtFinType1       37
# MasVnrArea          8
# MasVnrType          8
# Electrical          1
# BldgType            0
# Exterior2nd         0
# MSZoning            0
# BsmtFinSF1          0
# LotArea             0
# Street              0
# LotShape            0
# LandContour         0
# Foundation          0
# ExterCond           0
# ExterQual           0
# Utilities           0
# LotConfig           0
# Exterior1st         0
# Condition2          0
# RoofMatl            0
# RoofStyle           0
# YearRemodAdd        0
# YearBuilt           0
# OverallCond         0
# LandSlope           0
# Neighborhood        0
# ...

# %%
# Percentage of Missing Values -

(house_df.isnull().sum()*100/len(house_df)).sort_values(ascending=False)
# Out:
# PoolQC           99.520548
# MiscFeature      96.301370
# Alley            93.767123
# Fence            80.753425
# FireplaceQu      47.260274
# LotFrontage      17.739726
# GarageCond        5.547945
# GarageYrBlt       5.547945
# GarageType        5.547945
# GarageFinish      5.547945
# GarageQual        5.547945
# BsmtExposure      2.602740
# BsmtFinType2      2.602740
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtFinType1      2.534247
# MasVnrArea        0.547945
# MasVnrType        0.547945
# Electrical        0.068493
# BldgType          0.000000
# Exterior2nd       0.000000
# MSZoning          0.000000
# BsmtFinSF1        0.000000
# LotArea           0.000000
# Street            0.000000
# LotShape          0.000000
# LandContour       0.000000
# Foundation        0.000000
# ExterCond         0.000000
# ExterQual         0.000000
# Utilities         0.000000
# LotConfig         0.000000
# Exterior1st       0.000000
# Condition2        0.000000
# ...

# %%
house_df['PoolQC'] = house_df['PoolQC'].replace(np.nan,'No Pool')
house_df['MiscFeature'] = house_df['MiscFeature'].replace(np.nan,'No Feature')
house_df['Alley'] = house_df['Alley'].replace(np.nan,'No Alley')
house_df['Fence'] = house_df['Fence'].replace(np.nan,'No Fence')

# %%
house_df[house_df['FireplaceQu'].isnull()]['Fireplaces'].value_counts()
# Out:
# 0    690
# Name: Fireplaces, dtype: int64

# %%
house_df['FireplaceQu'] = house_df['FireplaceQu'].replace(np.nan,'No Fireplace')

# %%
(house_df.isnull().sum()*100/len(house_df)).sort_values(ascending=False)
# Out:
# LotFrontage      17.739726
# GarageFinish      5.547945
# GarageType        5.547945
# GarageQual        5.547945
# GarageCond        5.547945
# GarageYrBlt       5.547945
# BsmtFinType2      2.602740
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# BsmtCond          2.534247
# BsmtQual          2.534247
# MasVnrArea        0.547945
# MasVnrType        0.547945
# Electrical        0.068493
# ExterQual         0.000000
# Foundation        0.000000
# Exterior2nd       0.000000
# Exterior1st       0.000000
# RoofMatl          0.000000
# BsmtFinSF1        0.000000
# BsmtFinSF2        0.000000
# RoofStyle         0.000000
# BsmtUnfSF         0.000000
# ExterCond         0.000000
# YearRemodAdd      0.000000
# Heating           0.000000
# LotConfig         0.000000
# MSZoning          0.000000
# LotArea           0.000000
# Street            0.000000
# Alley             0.000000
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# ...

# %%
sns.heatmap(house_df.isnull(),cbar=False)
plt.show()

# %%
house_df['GarageFinish'] = house_df['GarageFinish'].replace(np.nan,'No Garage')
house_df['GarageType'] = house_df['GarageType'].replace(np.nan,'No Garage')
house_df['GarageQual'] = house_df['GarageQual'].replace(np.nan,'No Garage')
house_df['GarageCond'] = house_df['GarageCond'].replace(np.nan,'No Garage')

# %%
house_df['GarageAge'] = 2021 - house_df['GarageYrBlt']

# %%
house_df['GarageAge'] = house_df['GarageAge'].replace(np.nan,0)

# %%
house_df['BsmtExposure'] = house_df['BsmtExposure'].replace(np.nan,'No Basement')
house_df['BsmtFinType2'] = house_df['BsmtFinType2'].replace(np.nan,'No Basement')
house_df['BsmtFinType1'] = house_df['BsmtFinType1'].replace(np.nan,'No Basement')
house_df['BsmtQual'] = house_df['BsmtQual'].replace(np.nan,'No Basement')
house_df['BsmtCond'] = house_df['BsmtCond'].replace(np.nan,'No Basement')

# %%
house_df['MasVnrType'] = house_df['MasVnrType'].replace(np.nan,'None')
house_df['MasVnrArea'] = house_df['MasVnrArea'].replace(np.nan,0)

# %%
house_df['Electrical'] = house_df['Electrical'].mode()[0]

# %%
(house_df.isnull().sum()*100/len(house_df)).sort_values(ascending=False)
# Out:
# LotFrontage      17.739726
# GarageYrBlt       5.547945
# GarageAge         0.000000
# BsmtCond          0.000000
# Exterior2nd       0.000000
# MasVnrType        0.000000
# MasVnrArea        0.000000
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          0.000000
# BsmtExposure      0.000000
# RoofMatl          0.000000
# BsmtFinType1      0.000000
# BsmtFinSF1        0.000000
# BsmtFinType2      0.000000
# BsmtFinSF2        0.000000
# BsmtUnfSF         0.000000
# TotalBsmtSF       0.000000
# Heating           0.000000
# Exterior1st       0.000000
# RoofStyle         0.000000
# CentralAir        0.000000
# YearRemodAdd      0.000000
# MSZoning          0.000000
# LotArea           0.000000
# Street            0.000000
# Alley             0.000000
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# ...

# %%
lot_df = house_df[house_df['LotFrontage'].isnull()]
lot_df
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street     Alley LotShape  \
# 7            60       RL          NaN    10382   Pave  No Alley      IR1
# 12           20       RL          NaN    12968   Pave  No Alley      IR2
# 14           20       RL          NaN    10920   Pave  No Alley      IR1
# 16           20       RL          NaN    11241   Pave  No Alley      IR1
# 24           20       RL          NaN     8246   Pave  No Alley      IR1
# 31           20       RL          NaN     8544   Pave  No Alley      IR1
# 42           85       RL          NaN     9180   Pave  No Alley      IR1
# 43           20       RL          NaN     9200   Pave  No Alley      IR1
# 50           60       RL          NaN    13869   Pave  No Alley      IR2
# 64           60       RL          NaN     9375   Pave  No Alley      Reg
# 66           20       RL          NaN    19900   Pave  No Alley      Reg
# 76           20       RL          NaN     8475   Pave  No Alley      IR1
# ...

# %%
lot_df['LotShape'].value_counts()
# Out:
# IR1    167
# Reg     74
# IR2     15
# IR3      3
# Name: LotShape, dtype: int64

# %%
lot_df['Alley'].value_counts()
# Out:
# No Alley    254
# Grvl          3
# Pave          2
# Name: Alley, dtype: int64

# %%
house_df[house_df['Alley']=='No Alley']['LotFrontage'].median()
# Out:
# 70.0

# %%
house_df['LotFrontage'] = house_df['LotFrontage'].replace(np.nan,house_df[house_df['Alley']=='No Alley']['LotFrontage'].median())

# %%
house_df = house_df.drop('GarageYrBlt',axis=1)

# %%
(house_df.isnull().sum()*100/len(house_df)).sort_values(ascending=False)
# Out:
# GarageAge        0.0
# RoofStyle        0.0
# Exterior1st      0.0
# Exterior2nd      0.0
# MasVnrType       0.0
# MasVnrArea       0.0
# ExterQual        0.0
# ExterCond        0.0
# Foundation       0.0
# BsmtQual         0.0
# BsmtCond         0.0
# BsmtExposure     0.0
# BsmtFinType1     0.0
# BsmtFinSF1       0.0
# BsmtFinType2     0.0
# BsmtFinSF2       0.0
# BsmtUnfSF        0.0
# TotalBsmtSF      0.0
# Heating          0.0
# RoofMatl         0.0
# YearRemodAdd     0.0
# CentralAir       0.0
# YearBuilt        0.0
# MSZoning         0.0
# LotFrontage      0.0
# LotArea          0.0
# Street           0.0
# Alley            0.0
# LotShape         0.0
# LandContour      0.0
# Utilities        0.0
# LotConfig        0.0
# LandSlope        0.0
# Neighborhood     0.0
# Condition1       0.0
# Condition2       0.0
# BldgType         0.0
# HouseStyle       0.0
# OverallQual      0.0
# OverallCond      0.0
# HeatingQC        0.0
# Electrical       0.0
# Age              0.0
# ...

# %% [markdown]
# ### Summary Statistics :

# %%
house_df.describe()
# Out:
#        LotFrontage        LotArea  OverallQual  OverallCond    YearBuilt  \
# count  1460.000000    1460.000000  1460.000000  1460.000000  1460.000000
# mean     70.041096   10516.828082     6.099315     5.575342  1971.267808
# std      22.024031    9981.264932     1.382997     1.112799    30.202904
# min      21.000000    1300.000000     1.000000     1.000000  1872.000000
# 25%      60.000000    7553.500000     5.000000     5.000000  1954.000000
# 50%      70.000000    9478.500000     6.000000     5.000000  1973.000000
# 75%      79.000000   11601.500000     7.000000     6.000000  2000.000000
# max     313.000000  215245.000000    10.000000     9.000000  2010.000000
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  \
# count   1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    1984.865753   103.117123   443.639726    46.549315   567.240411
# std       20.645407   180.731373   456.098091   161.319273   441.866955
# ...

# %%
house_df.describe(include='all')
# Out:
#         MSSubClass MSZoning  LotFrontage        LotArea Street     Alley  \
# count       1460.0     1460  1460.000000    1460.000000   1460      1460
# unique        15.0        5          NaN            NaN      2         3
# top           20.0       RL          NaN            NaN   Pave  No Alley
# freq         536.0     1151          NaN            NaN   1454      1369
# mean           NaN      NaN    70.041096   10516.828082    NaN       NaN
# std            NaN      NaN    22.024031    9981.264932    NaN       NaN
# min            NaN      NaN    21.000000    1300.000000    NaN       NaN
# 25%            NaN      NaN    60.000000    7553.500000    NaN       NaN
# 50%            NaN      NaN    70.000000    9478.500000    NaN       NaN
# 75%            NaN      NaN    79.000000   11601.500000    NaN       NaN
# max            NaN      NaN   313.000000  215245.000000    NaN       NaN
#
#        LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# ...

# %% [markdown]
# ### Checking for Outliers :

# %%
plt.figure(figsize=(25,16))
house_df.plot(kind='box')
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(data=house_df,x='LotArea',y='SalePrice',hue='Neighborhood',palette='icefire')
plt.show()

# %%
q1 = house_df.quantile(0.25)
q3 = house_df.quantile(0.75)

IQR = q3 - q1

UL = q3 + IQR * 1.5
LL = q1 - IQR * 1.5

print(house_df.shape)

house_df[~((house_df < LL) | (house_df > UL)).any(axis = 1)]
# Out:
# (1460, 83)
#      MSSubClass MSZoning  LotFrontage  LotArea Street     Alley LotShape  \
# 0            60       RL         65.0     8450   Pave  No Alley      Reg
# 2            60       RL         68.0    11250   Pave  No Alley      IR1
# 4            60       RL         84.0    14260   Pave  No Alley      IR1
# 6            20       RL         75.0    10084   Pave  No Alley      Reg
# 10           20       RL         70.0    11200   Pave  No Alley      Reg
# ...         ...      ...          ...      ...    ...       ...      ...
# 1451         20       RL         78.0     9262   Pave  No Alley      Reg
# 1452        180       RM         35.0     3675   Pave  No Alley      Reg
# 1453         20       RL         90.0    17217   Pave  No Alley      Reg
# 1454         20       FV         62.0     7500   Pave      Pave      Reg
# 1455         60       RL         62.0     7917   Pave  No Alley      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
house_df[~((house_df < LL) & (house_df > UL)).any(axis = 1)].plot(kind='box')
plt.show()

# %%
# As we are losing over 50% of data points we will proceed futher with the original Data.

# %% [markdown]
# ### Checking the variable Correlation :

# %%
house_df.corr()
# Out:
#                LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# LotFrontage       1.000000  0.306689     0.234227    -0.052842   0.117555
# LotArea           0.306689  1.000000     0.105806    -0.005636   0.014228
# OverallQual       0.234227  0.105806     1.000000    -0.091932   0.572323
# OverallCond      -0.052842 -0.005636    -0.091932     1.000000  -0.375983
# YearBuilt         0.117555  0.014228     0.572323    -0.375983   1.000000
# YearRemodAdd      0.082775  0.013788     0.550684     0.073741   0.592855
# MasVnrArea        0.178690  0.103321     0.407252    -0.125694   0.311600
# BsmtFinSF1        0.215760  0.214103     0.239666    -0.046231   0.249503
# BsmtFinSF2        0.043298  0.111170    -0.059119     0.040229  -0.049107
# BsmtUnfSF         0.122249 -0.002618     0.308159    -0.136841   0.149040
# TotalBsmtSF       0.363366  0.260833     0.537808    -0.171098   0.391452
# 1stFlrSF          0.414246  0.299475     0.476224    -0.144203   0.281986
# ...

# %%
plt.figure(figsize=(30,30))
sns.heatmap(house_df.corr(),annot=True,cmap='icefire')
plt.show()

# %% [markdown]
# # Model Bulding :

# %% [markdown]
# ## Linear Regression Model

# %%
house_df = house_df.drop(['YearBuilt','MoSold','YrSold'],axis=1)

# %%
dummy_house = pd.get_dummies(house_df,drop_first=True)

# %%
from sklearn.model_selection import train_test_split
import statsmodels.api as sma
from statsmodels.api import OLS

X = dummy_house.drop('SalePrice',axis=1)
X = sma.add_constant(X)
y = house_df.SalePrice

Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,random_state=10,test_size=0.2)

# %%
model = OLS(ytrain,Xtrain).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     52.19
# Date:                Wed, 03 Mar 2021   Prob (F-statistic):               0.00
# Time:                        17:05:25   Log-Likelihood:                -13210.
# No. Observations:                1168   AIC:                         2.695e+04
# Df Residuals:                     905   BIC:                         2.828e+04
# Df Model:                         262
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
sig_feat = model.pvalues[model.pvalues<0.05].sort_values()
sig_feat.index
# Out:
# Index(['RoofMatl_WdShngl', 'RoofMatl_CompShg', 'RoofMatl_Membran',
#        'RoofMatl_WdShake', 'RoofMatl_Tar&Grv', 'Condition2_PosN', 'LotArea',
#        'KitchenQual_Gd', '2ndFlrSF', 'OverallCond', 'OverallQual',
#        'MiscFeature_TenC', 'KitchenQual_TA', 'TotalBsmtSF', 'BsmtQual_Gd',
#        'const', 'GarageQual_Fa', 'GrLivArea', 'GarageQual_TA', 'GarageQual_Gd',
#        'RoofMatl_Roll', 'GarageQual_Po', 'BsmtFinSF1', 'Condition1_Norm',
#        'ExterQual_Gd', 'LandSlope_Sev', 'GarageCond_Po', 'GarageCond_TA',
#        'GarageCond_Fa', 'PoolQC_Fa', 'GarageCond_Gd', 'ExterQual_TA',
#        'PoolQC_Gd', 'MasVnrArea', 'WoodDeckSF', 'MSZoning_FV',
#        'Neighborhood_Edwards', 'BsmtExposure_Gd', 'BsmtQual_TA', 'Street_Pave',
#        'RoofStyle_Shed', 'Neighborhood_Mitchel', 'MSZoning_RL',
#        'LotConfig_CulDSac', 'MSZoning_RM', 'PoolArea', 'Neighborhood_StoneBr',
#        'MSZoning_RH', 'MonthSold_Oct', 'LandSlope_Mod', 'BedroomAbvGr',
# ...

# %%
insig_feat = model.pvalues[model.pvalues>0.05].sort_values(ascending=False)
insig_feat.index
# Out:
# Index(['Exterior1st_MetalSd', 'HouseStyle_SFoyer', 'SaleType_WD',
#        'BsmtFinType1_Rec', 'MiscFeature_Shed', 'LotConfig_Inside',
#        'MiscFeature_Othr', 'MiscFeature_No Feature', 'Exterior1st_Stucco',
#        'Exterior1st_CemntBd',
#        ...
#        'Condition1_Feedr', 'MonthSold_Dec', 'GarageArea',
#        'SaleCondition_AdjLand', 'HeatingQC_TA', 'BsmtExposure_No',
#        'Neighborhood_NoRidge', 'SaleCondition_Normal', 'GarageType_Basment',
#        'LandContour_Lvl'],
#       dtype='object', length=212)

# %%
house_copy = house_df.copy()

# %%
house_copy = house_copy.drop(['SaleType','Exterior2nd','BsmtFinType1','SaleCondition','MSSubClass','Street'
                             ,'Neighborhood','BsmtFinType1','HouseStyle','Exterior1st','Condition2','Utilities',
                             'GarageFinish','Alley','Age','GarageAge','GarageQual','GarageCond','MonthSold',
                             'MasVnrType','LotConfig','FireplaceQu','MiscFeature','Heating','PavedDrive','BsmtCond',
                             'BsmtUnfSF','Foundation','ExterQual','FullBath','RoofStyle','Foundation','Condition1'],axis=1)

print(house_copy.shape)
dummy_house = pd.get_dummies(house_copy,drop_first=True)
# Out:
# (1460, 49)

# %%
X = dummy_house.drop('SalePrice',axis=1)
X = sma.add_constant(X)
y = house_df.SalePrice

Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,random_state=10,test_size=0.2)

# %%
tuned_model = OLS(ytrain,Xtrain).fit()
tuned_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.885
# Method:                 Least Squares   F-statistic:                     98.22
# Date:                Wed, 03 Mar 2021   Prob (F-statistic):               0.00
# Time:                        17:05:25   Log-Likelihood:                -13524.
# No. Observations:                1168   AIC:                         2.723e+04
# Df Residuals:                    1075   BIC:                         2.771e+04
# Df Model:                          92
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
ypred_tuned = tuned_model.predict(Xtest)

# %%
sig_feat = tuned_model.pvalues[model.pvalues<0.05].sort_values()
sig_feat
# Out:
# RoofMatl_WdShngl    2.736345e-25
# RoofMatl_CompShg    1.555701e-21
# RoofMatl_WdShake    1.367302e-20
# RoofMatl_Membran    3.467503e-20
# RoofMatl_Tar&Grv    3.168800e-19
# KitchenQual_Gd      1.233479e-15
# OverallQual         2.689061e-15
# BsmtQual_Gd         1.719480e-13
# KitchenQual_TA      2.022921e-13
# 2ndFlrSF            2.282133e-11
# RoofMatl_Roll       8.937547e-11
# OverallCond         2.511481e-10
# TotalBsmtSF         1.975091e-09
# BsmtQual_TA         2.403131e-09
# const               2.884637e-09
# BsmtFinSF1          2.230023e-06
# GrLivArea           9.379801e-06
# LotArea             1.251126e-05
# BedroomAbvGr        4.542951e-05
# KitchenQual_Fa      1.308074e-04
# MSZoning_FV         2.284072e-04
# PoolQC_Fa           3.203360e-04
# LandContour_HLS     6.596919e-04
# PoolQC_Gd           8.102829e-04
# PoolArea            1.528777e-03
# MasVnrArea          2.091372e-03
# MSZoning_RL         5.589098e-03
# LandSlope_Mod       5.762190e-03
# ...

# %%
insig_feat = tuned_model.pvalues[model.pvalues>0.05].sort_values(ascending=False)
insig_feat
# Out:
# LotShape_IR3                8.921656e-01
# ExterCond_Po                8.864550e-01
# BsmtQual_No Basement        8.858074e-01
# BsmtFinType2_No Basement    8.858074e-01
# BsmtExposure_No Basement    8.858074e-01
# BsmtFinType2_Unf            8.559665e-01
# MiscVal                     8.457408e-01
# BsmtExposure_Mn             8.444767e-01
# EnclosedPorch               8.172952e-01
# Functional_Maj2             7.000434e-01
# BsmtFullBath                5.811957e-01
# BsmtFinType2_Rec            5.383005e-01
# ExterCond_Fa                5.188916e-01
# Functional_Mod              4.819782e-01
# LotFrontage                 3.988513e-01
# Fence_MnWw                  3.948749e-01
# BsmtFinType2_GLQ            3.804069e-01
# LandContour_Low             3.416200e-01
# YearRemodAdd                2.996204e-01
# LotShape_Reg                2.885106e-01
# ExterCond_TA                2.859320e-01
# BldgType_2fmCon             2.820436e-01
# BsmtFinType2_BLQ            2.588895e-01
# ...

# %%
from sklearn import metrics

# %%
print('RMSE :',np.sqrt(metrics.mean_squared_error(ytest,ypred_tuned)))

print('MAE :',metrics.mean_absolute_error(ytest,ypred_tuned))
# Out:
# RMSE : 55631.45077490558
# MAE : 23569.929550309138

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
print('MAPE :',mean_absolute_percentage_error(ytest,ypred_tuned))
# Out:
# MAPE : 14.758780133480071

# %%
print('MAE :',metrics.mean_absolute_percentage_error(ytest,ypred_tuned))
# Out:
# MAE : 0.1475878013348007

# %%
X = dummy_house.drop('SalePrice',axis=1)
X = sma.add_constant(X)
y1 = np.log(house_df.SalePrice)

Xtrain,Xtest,ytrain,ytest = train_test_split(X,y1,random_state=10,test_size=0.2)

# %%
log_tuned_model = OLS(ytrain,Xtrain).fit()
log_tuned_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.915
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     125.8
# Date:                Wed, 03 Mar 2021   Prob (F-statistic):               0.00
# Time:                        17:05:25   Log-Likelihood:                 870.34
# No. Observations:                1168   AIC:                            -1555.
# Df Residuals:                    1075   BIC:                            -1084.
# Df Model:                          92
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
ypred_log_tuned = log_tuned_model.predict(Xtest)

# %%
ypred_log_tuned = np.exp(ypred_log_tuned)
ytest_log_tuned = np.exp(ytest)

# %%
print('RMSE :',np.sqrt(metrics.mean_squared_error(ytest_log_tuned,ypred_log_tuned)))

print('MAE :',metrics.mean_absolute_error(ytest_log_tuned,ypred_log_tuned))
# Out:
# RMSE : 27664.21968586295
# MAE : 18084.21264949485

# %%
print('MAPE :',mean_absolute_percentage_error(ytest_log_tuned,ypred_log_tuned))
# Out:
# MAPE : 10.428314300395158

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

lrfit = LinearRegression()
n = 10

cross_val_score(estimator=lrfit,X=Xtrain,y=ytrain,scoring='r2',cv = n)
# Out:
# array([0.45862577, 0.92375401, 0.90211043, 0.87704274, 0.91988564,
#        0.51729723, 0.71283653, 0.86553417, 0.92354791, 0.87088886])

# %% [markdown]
# ## Random Forest Regressor:

# %%
X = dummy_house.drop('SalePrice',axis=1)
X = sma.add_constant(X)
y = house_df.SalePrice

Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,random_state=10,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(Xtrain,ytrain)
# Out:
# RandomForestRegressor()

# %%
ypred_rf =rf.predict(Xtest)

# %%
print('RMSE :',np.sqrt(metrics.mean_squared_error(ytest,ypred_rf)))

print('MAE :',metrics.mean_absolute_error(ytest,ypred_rf))

print('MAE :',metrics.mean_absolute_percentage_error(ytest,ypred_rf))
# Out:
# RMSE : 28742.264280786665
# MAE : 19007.138609589038
# MAE : 0.10900004813871635

# %%
house_copy = house_df.copy()

# %%
house_copy = house_copy.drop(['SaleType','Exterior2nd','BsmtFinType1','SaleCondition','MSSubClass','Street'
                             ,'Neighborhood','BsmtFinType1','HouseStyle','Exterior1st','Condition2','Utilities',
                             'GarageFinish','Alley','Age','GarageAge','GarageQual','GarageCond','MonthSold',
                             'MasVnrType','LotConfig','FireplaceQu','MiscFeature','Heating','PavedDrive','BsmtCond',
                             'BsmtUnfSF','Foundation','ExterQual','FullBath','RoofStyle','Foundation','Condition1'],axis=1)

print(house_copy.shape)
dummy_house = pd.get_dummies(house_copy,drop_first=True)
# Out:
# (1460, 49)

# %%
X = dummy_house.drop('SalePrice',axis=1)
X = sma.add_constant(X)
y = house_df.SalePrice

Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,random_state=10,test_size=0.2)

# %%
rf_tuned = RandomForestRegressor()
rf_tuned.fit(Xtrain,ytrain)
# Out:
# RandomForestRegressor()

# %%
tuned_ypred_rf =rf_tuned.predict(Xtest)

# %%
print('RMSE :',np.sqrt(metrics.mean_squared_error(ytest,tuned_ypred_rf)))

print('MAE :',metrics.mean_absolute_error(ytest,tuned_ypred_rf))

print('MAE :',metrics.mean_absolute_percentage_error(ytest,tuned_ypred_rf))
# Out:
# RMSE : 28104.224371043187
# MAE : 18514.98675570776
# MAE : 0.10699338113797252

# %%
X = dummy_house.drop('SalePrice',axis=1)
X = sma.add_constant(X)
y1 = np.log(house_df.SalePrice)

Xtrain,Xtest,ytrain,ytest = train_test_split(X,y1,random_state=10,test_size=0.2)

# %%
rf_log_tuned = RandomForestRegressor()
rf_log_tuned.fit(Xtrain,ytrain)
# Out:
# RandomForestRegressor()

# %%
ypred_log_tuned = rf_log_tuned.predict(Xtest)

# %%
ypred_log_tuned = np.exp(ypred_log_tuned)
ytest_log_tuned = np.exp(ytest)

# %%
print('RMSE :',np.sqrt(metrics.mean_squared_error(ytest_log_tuned,ypred_log_tuned)))

print('MAE :',metrics.mean_absolute_error(ytest_log_tuned,ypred_log_tuned))

print('MAE :',metrics.mean_absolute_percentage_error(ytest_log_tuned,ypred_log_tuned))
# Out:
# RMSE : 29245.62042750416
# MAE : 18684.15781072124
# MAE : 0.10579063745410089

# %%
rfmodel = RandomForestRegressor()
n = 10

cross_val_score(estimator=rfmodel,X=Xtrain,y=ytrain,scoring='r2',cv = n)
# Out:
# array([0.85583984, 0.88646135, 0.88719874, 0.85370194, 0.88218809,
#        0.85803455, 0.82499171, 0.82967649, 0.88925295, 0.85483843])

# %% [markdown]
# ## Decision Tree Regressor:

# %%
X = dummy_house.drop('SalePrice',axis=1)
X = sma.add_constant(X)
y = house_df.SalePrice

Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,random_state=10,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(Xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
ypred_dt =dt.predict(Xtest)

# %%
print('RMSE :',np.sqrt(metrics.mean_squared_error(ytest,ypred_dt)))

print('MAE :',metrics.mean_absolute_error(ytest,ypred_dt))

print('MAE :',metrics.mean_absolute_percentage_error(ytest,ypred_dt))
# Out:
# RMSE : 35903.17670266053
# MAE : 24921.26712328767
# MAE : 0.14949192050195562

# %%
house_copy = house_df.copy()

# %%
house_copy = house_copy.drop(['SaleType','Exterior2nd','BsmtFinType1','SaleCondition','MSSubClass','Street'
                             ,'Neighborhood','BsmtFinType1','HouseStyle','Exterior1st','Condition2','Utilities',
                             'GarageFinish','Alley','Age','GarageAge','GarageQual','GarageCond','MonthSold',
                             'MasVnrType','LotConfig','FireplaceQu','MiscFeature','Heating','PavedDrive','BsmtCond',
                             'BsmtUnfSF','Foundation','ExterQual','FullBath','RoofStyle','Foundation','Condition1'],axis=1)

print(house_copy.shape)
dummy_house = pd.get_dummies(house_copy,drop_first=True)
# Out:
# (1460, 49)

# %%
X = dummy_house.drop('SalePrice',axis=1)
X = sma.add_constant(X)
y = house_df.SalePrice

Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,random_state=10,test_size=0.2)

# %%
dt_tuned = DecisionTreeRegressor()
dt_tuned.fit(Xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
tuned_ypred_dt =dt_tuned.predict(Xtest)

# %%
print('RMSE :',np.sqrt(metrics.mean_squared_error(ytest,tuned_ypred_dt)))

print('MAE :',metrics.mean_absolute_error(ytest,tuned_ypred_dt))

print('MAE :',metrics.mean_absolute_percentage_error(ytest,tuned_ypred_dt))
# Out:
# RMSE : 37753.81440322488
# MAE : 26273.95205479452
# MAE : 0.1553672113111068

# %%
X = dummy_house.drop('SalePrice',axis=1)
X = sma.add_constant(X)
y1 = np.log(house_df.SalePrice)

Xtrain,Xtest,ytrain,ytest = train_test_split(X,y1,random_state=10,test_size=0.2)

# %%
dt_log_tuned = DecisionTreeRegressor()
dt_log_tuned.fit(Xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
ypred_log_tuned = dt_log_tuned.predict(Xtest)

# %%
ypred_log_tuned = np.exp(ypred_log_tuned)
ytest_log_tuned = np.exp(ytest)

# %%
print('RMSE :',np.sqrt(metrics.mean_squared_error(ytest_log_tuned,ypred_log_tuned)))

print('MAE :',metrics.mean_absolute_error(ytest_log_tuned,ypred_log_tuned))

print('MAE :',metrics.mean_absolute_percentage_error(ytest_log_tuned,ypred_log_tuned))
# Out:
# RMSE : 37666.162495267046
# MAE : 26132.208904109575
# MAE : 0.15563964620625106

# %%
dtmodel = DecisionTreeRegressor()
n = 10

cross_val_score(estimator=rfmodel,X=Xtrain,y=ytrain,scoring='r2',cv = n)
# Out:
# array([0.8602139 , 0.89222064, 0.89581004, 0.85019749, 0.88247587,
#        0.85102837, 0.81518535, 0.83339641, 0.89358933, 0.85296162])
